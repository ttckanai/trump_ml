# %% [markdown]
# ## パーセプトロンによる分類学習

# %% [markdown]
# ### トランプデッキの読み込み

# %%
import pandas as pd

# %%
deck = pd.read_csv("./TrumpDeck.csv")
deck.sample(5)
# Out:
#     Id Rank Suit  Num  SuitOrder  Color   Face EvenOdd  Royal  Symmetry  \
# 30  5H    5    H    5          3    red  False     odd  False     False
# 34  9H    9    H    9          3    red  False     odd  False     False
# 10  JC    J    C   11          1  black   True     odd   True      True
# 20  8D    8    D    8          2    red  False    even  False      True
# 37  QH    Q    H   12          3    red   True    even   True      True
#
#     Asymmetry
# 30       True
# 34       True
# 10      False
# 20      False
# 37      False

# %% [markdown]
# ### 教師データの設定

# %%
features = ["Suit","Num","Color","Face","EvenOdd","Royal"]
target = "Asymmetry"
X = deck[features]
y = deck[target]
X = pd.get_dummies(X, drop_first=True)

# %%
X.sample(5)
# Out:
#     Num   Face  Royal  Suit_D  Suit_H  Suit_S  Color_red  EvenOdd_odd
# 16    4  False  False       1       0       0          1            0
# 40    2  False  False       0       0       1          0            0
# 19    7  False  False       1       0       0          1            1
# 36   11   True   True       0       1       0          1            1
# 49   11   True   True       0       0       1          0            1

# %%
y.sample(5)
# Out:
# 27    False
# 6      True
# 42    False
# 22    False
# 31     True
# Name: Asymmetry, dtype: bool

# %% [markdown]
# ### 学習データと評価データへの分割

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
X_test.head()
# Out:
#     Num   Face  Royal  Suit_D  Suit_H  Suit_S  Color_red  EvenOdd_odd
# 28    3  False  False       0       1       0          1            1
# 37   12   True   True       0       1       0          1            0
# 11   12   True   True       0       0       0          0            0
# 34    9  False  False       0       1       0          1            1
# 2     3  False  False       0       0       0          0            1

# %%
y_test.head()
# Out:
# 28     True
# 37    False
# 11    False
# 34     True
# 2      True
# Name: Asymmetry, dtype: bool

# %% [markdown]
# ### 法則の推測

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron()

# %%
type(clf)
# Out:
# sklearn.linear_model._perceptron.Perceptron

# %%
clf.fit(X_train, y_train)
# Out:
# Perceptron()

# %%
from sklearn.metrics import confusion_matrix
y_train_pred = clf.predict(X_train)
conf_train = confusion_matrix(y_train, y_train_pred)
index = pd.MultiIndex.from_product([["Actual"],clf.classes_])
columns = pd.MultiIndex.from_product([["Predicted"],clf.classes_])
conf_train = pd.DataFrame(conf_train,
                          index=index,
                          columns=columns)

# %%
conf_train
# Out:
#              Predicted
#                  False True
# Actual False        18     0
#        True          5     3

# %% [markdown]
# ### 回答

# %%
y_test_pred = clf.predict(X_test)
y_test_pred = pd.Series(y_test_pred, index=y_test.index)
y_test_pred.name = "prediction"
y_test_pred
# Out:
# 28    False
# 37    False
# 11    False
# 34    False
# 2      True
# 30    False
# 40     True
# 32    False
# 26    False
# 4     False
# 10    False
# 22    False
# 31    False
# 29    False
# 42    False
# 43    False
# 7     False
# 14    False
# 33    False
# 50    False
# 18    False
# 49    False
# 35    False
# 15    False
# 5     False
# 27    False
# Name: prediction, dtype: bool

# %%
pd.concat([X_test, y_test_pred], axis="columns")
# Out:
#     Num   Face  Royal  Suit_D  Suit_H  Suit_S  Color_red  EvenOdd_odd  \
# 28    3  False  False       0       1       0          1            1
# 37   12   True   True       0       1       0          1            0
# 11   12   True   True       0       0       0          0            0
# 34    9  False  False       0       1       0          1            1
# 2     3  False  False       0       0       0          0            1
# 30    5  False  False       0       1       0          1            1
# 40    2  False  False       0       0       1          0            0
# 32    7  False  False       0       1       0          1            1
# 26    1  False   True       0       1       0          1            1
# 4     5  False  False       0       0       0          0            1
# 10   11   True   True       0       0       0          0            1
# 22   10  False   True       1       0       0          1            0
# 31    6  False  False       0       1       0          1            0
# 29    4  False  False       0       1       0          1            0
# 42    4  False  False       0       0       1          0            0
# 43    5  False  False       0       0       1          0            1
# 7     8  False  False       0       0       0          0            0
# 14    2  False  False       1       0       0          1            0
# 33    8  False  False       0       1       0          1            0
# 50   12   True   True       0       0       1          0            0
# 18    6  False  False       1       0       0          1            0
# 49   11   True   True       0       0       1          0            1
# 35   10  False   True       0       1       0          1            0
# 15    3  False  False       1       0       0          1            1
# 5     6  False  False       0       0       0          0            0
# 27    2  False  False       0       1       0          1            0
#
#     prediction
# 28       False
# 37       False
# 11       False
# 34       False
# 2         True
# 30       False
# 40        True
# 32       False
# 26       False
# 4        False
# 10       False
# 22       False
# 31       False
# 29       False
# 42       False
# 43       False
# 7        False
# 14       False
# 33       False
# 50       False
# 18       False
# 49       False
# 35       False
# 15       False
# 5        False
# 27       False

# %% [markdown]
# ### 答え合わせ

# %%
from sklearn.metrics import confusion_matrix
conf_test = confusion_matrix(y_test, y_test_pred)
conf_test = pd.DataFrame(conf_test,
                          index=index,
                          columns=columns)

# %%
conf_test
# Out:
#              Predicted
#                  False True
# Actual False        15     1
#        True          9     1

# %% [markdown]
# ### 点数計算

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
acc_test = accuracy_score(y_test, y_test_pred)
pre_test = precision_score(y_test, y_test_pred)
rec_test = recall_score(y_test, y_test_pred)

print(f"正解率 : {acc_test}")
print(f"適合率 : {pre_test}")
print(f"検出率 : {rec_test}")
# Out:
# 正解率 : 0.6153846153846154
# 適合率 : 0.5
# 検出率 : 0.1

# %% [markdown]
# ### パーセプトロンの動作原理

# %%
clf.coef_
# Out:
# array([[ -7., -12., -14.,  -7.,  -2.,   9.,  -9.,  17.]])

# %%
X_train.head()
# Out:
#     Num   Face  Royal  Suit_D  Suit_H  Suit_S  Color_red  EvenOdd_odd
# 16    4  False  False       1       0       0          1            0
# 51   13   True   True       0       0       1          0            1
# 20    8  False  False       1       0       0          1            0
# 45    7  False  False       0       0       1          0            1
# 8     9  False  False       0       0       0          0            1

# %%
clf.intercept_
# Out:
# array([8.])

# %%
((X_test * clf.coef_).sum(axis="columns") + clf.intercept_) > 0
# Out:
# 28    False
# 37    False
# 11    False
# 34    False
# 2      True
# 30    False
# 40     True
# 32    False
# 26    False
# 4     False
# 10    False
# 22    False
# 31    False
# 29    False
# 42    False
# 43    False
# 7     False
# 14    False
# 33    False
# 50    False
# 18    False
# 49    False
# 35    False
# 15    False
# 5     False
# 27    False
# dtype: bool

# %%
((X_test * clf.coef_).sum(axis="columns") + clf.intercept_) > 0

# %%
y_test_pred
# Out:
# 28    False
# 37    False
# 11    False
# 34    False
# 2      True
# 30    False
# 40     True
# 32    False
# 26    False
# 4     False
# 10    False
# 22    False
# 31    False
# 29    False
# 42    False
# 43    False
# 7     False
# 14    False
# 33    False
# 50    False
# 18    False
# 49    False
# 35    False
# 15    False
# 5     False
# 27    False
# Name: prediction, dtype: bool
